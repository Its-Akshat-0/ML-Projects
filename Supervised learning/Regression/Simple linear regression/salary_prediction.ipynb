# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
df=pd.read_csv("Salary_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary    random
# 0            0              1.2   39344.0  0.569365
# 1            1              1.4   46206.0  0.422954
# 2            2              1.6   37732.0  0.705941
# 3            3              2.1   43526.0  0.689806
# 4            4              2.3   39892.0  0.393973
# 5            5              3.0   56643.0  0.053060
# 6            6              3.1   60151.0  0.340622
# 7            7              3.3   54446.0  0.544367
# 8            8              3.3   64446.0  0.553916
# 9            9              3.8   57190.0  0.406223
# 10          10              4.0   63219.0  0.743545
# 11          11              4.1   55795.0  0.362380
# 12          12              4.1   56958.0  0.204490
# 13          13              4.2   57082.0  0.274714
# 14          14              4.6   61112.0  0.745823
# 15          15              5.0   67939.0  0.305138
# 16          16              5.2   66030.0  0.974011
# 17          17              5.4   83089.0  0.005588
# 18          18              6.0   81364.0  0.201671
# 19          19              6.1   93941.0  0.462686
# 20          20              6.9   91739.0  0.279062
# 21          21              7.2   98274.0  0.520152
# 22          22              8.0  101303.0  0.224661
# 23          23              8.3  113813.0  0.844847
# 24          24              8.8  109432.0  0.843261
# 25          25              9.1  105583.0  0.216769
# 26          26              9.6  116970.0  0.923241
# 27          27              9.7  112636.0  0.339880
# 28          28             10.4  122392.0  0.563528
# 29          29             10.6  121873.0  0.606621

# %%
x=df[["YearsExperience","random"]]
y=df["Salary"]

# %%
print(x.shape)
print(y.shape)
# Out:
# (30, 2)
# (30,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
sns.scatterplot(x="YearsExperience",y="Salary",data=df)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn.linear_model import LinearRegression

# %%
ls=LinearRegression()
ls.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ls.coef_
# Out:
# array([ 9440.64250105, -1658.52739515])

# %%
ls.intercept_
# Out:
# np.float64(25111.28002589645)

# %%
plt.scatter(df["YearsExperience"],df["Salary"])
plt.plot(X_test,ls.predict(X_test))
# Out:
# [<matplotlib.lines.Line2D at 0x22ca8cf4410>,
#  <matplotlib.lines.Line2D at 0x22ca8cf4550>]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=ls.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 6388.267629165616

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 51121869.68616942

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 7149.955921973885

# %%
print("r2_score",r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# r2_score 0.8999172363673456

# %%
X_test.shape
# Out:
# (6, 2)

# %%
#Adjusted r2_score
1-((1-r2)*(6-1)/(6-1-1))
# Out:
# 0.8748965454591819

# %%
df["random"]=np.random.random(30)
