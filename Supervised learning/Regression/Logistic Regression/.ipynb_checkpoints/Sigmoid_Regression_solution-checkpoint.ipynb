# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=30)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
class mylor:
    def __init__(self):
        self.intercept_=None
        self.coef_=None

    def sigmoid(self,y):
        return (1/(1+np.exp(-y)))
    def fit(self,X,y):
        X=np.insert(X,0,1,axis=1)
        weights = np.ones(X.shape[1])
        lr=0.1a
        

        for i in range(5000):
            y_pred=self.sigmoid(np.dot(X,weights))
            weights=weights+(lr*np.dot((y-y_pred),X))/X.shape[0]
        return weights[0],weights[1:]

# %%
model=mylor()

# %%
intercept_,coef_ = mylor.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 intercept_,coef_ = mylor.fit(X,y)
#
# TypeError: mylor.fit() missing 1 required positional argument: 'y'
